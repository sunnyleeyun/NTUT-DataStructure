# %% [markdown]
# ## Data Structures 2021 Fall
# ### Homework 5
# ### Due: Jan 18, 2022
#
# ### SID:110054316
# ### Name: 李昀

# %%
import re

# Node class 
class Hnode:
    def __init__(self, key, item):
        self.key = key
        self.item = item
        self.parent = None
        self.right = None
        self.left = None

    def getKey(self):
        return self.key

    def getItem(self):
        return self.item

    def getRightChild(self):
        return self.right

    def getLeftChild(self):
        return self.left

    def getParent(self):
        return self.parent

    def hasRightChild(self):
        return (self.right!=None)

    def hasLeftChild(self):
        return (self.left!=None)

    def isRoot(self):
        return (self.parent==None)

    def isLeaf(self):
        return ((self.right==None)and(self.left==None))

    def isRightChild(self):
        return (self.parent.right==self)

    def isLeftChild(self):
        return (self.parent.left==self)

    def setParent(self, p):
        self.parent=p

    def setKey(self, key):
        self.key = key

    def setItem(self, item):
        self.item = item
        
    def addRightChild(self, hnode):
        self.right=hnode
        hnode.setParent(self)

    def addLeftChild(self, hnode):
        self.left=hnode
        hnode.setParent(self)

# Heap class 
class Heap:
    def __init__(self):
        self.root=None
        self.last=None
        self.size=0

    def isEmpty(self):
        return (self.size==0)

    def getSize(self):
        return self.size

    def getRoot(self):
        return self.root

    def getLast(self):
        return self.last

    def getHighestPriority(self):
        return self.root.getKey()

    def setRoot(self, hnode):
        self.root=hnode

    def setLast(self, hnode):
        self.last=hnode

#
# methods for heaps
#

    #
    # downward adjustment from current node
    #
    def downwardHeapify(self,current):
        if(current.isLeaf()!=True): #確定不是葉結點       
            if(current.hasRightChild()):
                right=current.right.getKey()
            else:
                right=None
            if(current.hasLeftChild()):
                left=current.left.getKey()
            else:
                left=None

            if(right!=None):#如果右邊有小孩(有兩個小孩)
                small=current.left if right>left else current.right
                if(current.getKey()>small.getKey()):
                    c_p=current.parent
                    c_r=current.right
                    c_l=current.left
                    s_p=small.parent
                    s_r=small.right
                    s_l=small.left
                    if (small.isRightChild()):#如果要交換的key值小結點是當前的右結點
                        
                        #處理交換的兩個 Node 的 parent 和 child
                        if(c_p!=None and current.isRightChild()):
                            c_p.right=small
                        if(c_p!=None and current.isLeftChild()):
                            c_p.left=small
                        current.left.parent=small
                        if(small.hasRightChild()):
                            small.right.parent=current
                        if(small.hasLeftChild()):
                            small.left.parent=current
                        #處理兩個 node 的交換
                        small.parent=c_p
                        small.left=c_l
                        small.right=current
                        current.parent=small
                        current.left=s_l
                        current.right=s_r
                        self.downwardHeapify(current)
                    else:#要交換的是左小結點
                        
                        #處理交換的兩個 Node 的 parent 和 child
                        if(c_p!=None and current.isRightChild()):
                            c_p.right=small
                        if(c_p!=None and current.isLeftChild()):
                            c_p.left=small
                        current.right.parent=small
                        if(small.hasRightChild()):
                            small.right.parent=current
                        if(small.hasLeftChild()):
                            small.left.parent=current
                        
                        small.parent=c_p
                        small.left=current
                        small.right=c_r
                        current.parent=small
                        current.left=s_l
                        current.right=s_r
                        self.downwardHeapify(current)
                    
                    if(small.isRoot()):
                        self.setRoot(small)
                                         
                        
            else:#只有一個小孩(只有左小孩)
                if(current.getKey()>current.left.getKey()):
                    if(c_p!=None and current.isRightChild()):
                        c_p.right=small
                    if(c_p!=None and current.isLeftChild()):
                        c_p.left=small
                    c_p=current.parent
                    c_r=current.right
                    c_l=current.left
                    current.left.parent=c_p
                    current.left.left=current
                    current.left.right=None
                    current.parent=c_l
                    current.left=None
                    current.right=None
                    if(current.parent.isRoot()):
                        self.setRoot(current.parent)
        
        
                
            

    #
    # upward adjustment toward the root from the current node
    #
    def upwardHeapify(self, current): #有問題
        if(current.isRoot()!=True):
            if(current.getKey() < current.parent.getKey()):
                c_p=current.parent
                c_r=current.right
                c_l=current.left
                p_p=current.parent.parent
                p_r=current.parent.right
                p_l=current.parent.left
                
                if(c_p.parent!=None and c_p.isLeftChild()):
                    c_p.parent.left=current
                if(c_p.parent!=None and c_p.isRightChild()):
                    c_p.parent.right=current
                if(current.left!=None):
                    current.left.parent=c_p
                if(current.right!=None):
                    current.right.parent=c_p
                    
                if(current.isLeftChild()):
                    if(p_r!=None):
                        p_r.parent=current
                    current.parent.parent=current
                    current.parent.right=c_r
                    current.parent.left=c_l
                    current.parent=p_p
                    current.left=c_p
                    current.right=p_r
                else:
                    if(p_l!=None):
                        p_l.parent=current
                    current.parent.parent=current
                    current.parent.right=c_r
                    current.parent.left=c_l
                    current.parent=p_p
                    current.left=p_l
                    current.right=c_p
                    
                
                self.upwardHeapify(current)
                if(current.isRoot()):
                    self.setRoot(current)
                

                


    #
    # The most important operation for a heap, remove_Min (extract_Min())
    #
    def removeMin(self):
        if(self.size==0):
            print("The heap is empty and no entry can be removed")
        elif(self.size==1):
            self.size=0
            self.root=None
            self.last=None
            print("The heap is now empty")
        else:
            self.size-=1
            r_l=self.root.left
            r_r=self.root.right
            if (self.last.isRightChild()):
                self.last.parent.right=None
            else:
                self.last.parent.left=None
            self.last.parent=None
            self.last.right=r_r
            self.last.left=r_l
            if(r_l!=None):
                r_l.parent=self.last
            if(r_r!=None):
                r_r.parent=self.last
            self.downwardHeapify(self.last)

            #設定Last node
            a=copy.deepcopy(self.size)
            X=d2by(a)
            A=[]
            while a>0:
                A.append(next(X))
                a=math.floor(a/2)
            A.pop()
            node=self.root
            while len(A)>0:
                if(A.pop()==0):
                    node=node.left
                else:
                    node=node.right
            self.setLast(node)
            
        
        

    #
    # Another important operation for a heap, insertion() (add())
    #
    def Insert(self, hnode):
        
        if(self.size==0):
            self.size=1
            self.root=hnode
            self.last=hnode
        else:
            self.size+=1

            #找到新加入的結點
            a=copy.deepcopy(self.size)
            X=d2by(a)
            A=[]
            while a>0:
                A.append(next(X))
                a=math.floor(a/2)
            A.pop()
            print(len(A))
            node=self.root #要插入的結點位置
            node_p=None #插入結點位置的parent
            while len(A)>0:
                if(A.pop()==0):
                    node_p=node
                    node=node.left
                else:
                    node_p=node
                    node=node.right

            #加入
        
            if(node_p.hasLeftChild()):
                node_p.right=hnode
                hnode.parent=node_p
            else:
                node_p.left=hnode
                hnode.parent=node_p
            
            self.upwardHeapify(hnode)

            #設定Last node
            a=copy.deepcopy(self.size)
            X=d2by(a)
            A=[]
            while a>0:
                A.append(next(X))
                a=math.floor(a/2)
            A.pop()
            node=self.root
            while len(A)>0:
                if(A.pop()==0):
                    node=node.left
                else:
                    node=node.right
            self.setLast(node)
            

    #
    # For management, print the heap in pre-order
    #
    def printHeapPreOrder(self, i):
        k = i.getKey()
        d = i.getItem()
        
        prefix = ""
        if i.isRoot():
            prefix = "Root"
        elif i.isLeaf():
            prefix = "Leaf"
        else:
            prefix = "Node"
        
        print(prefix,"[",k,d,"]")
        
        if i.left:
            self.printHeapPreOrder(i.left)
        if i.right:
            self.printHeapPreOrder(i.right)

# decimal to binary using yield
def d2by(x):
    while x>0 :
        x,r=divmod(x,2)
        yield r 

# function for starting the task
def HeapwithEntriesInserted():
    #
    # read the input information from the default input text file into an
    # entry list, entry_list
    #
    
    
    #
    # initiating a heap object h
    #
    h=Heap()
    
    
    #
    # Do something here to build the heap
    #
    with open('inFile.txt', 'r') as f:
        for line in f:
            a, b = line.strip().split()
            n = Hnode(int(a), b)
            h.Insert(n)
            if 'str' in line:
                break
    
    #---------------------Print as the example on the homework sheet --------
    #                       will be adapted with the input
    #
    print("Heap size=", h.getSize(), "The highest priority is ", h.getHighestPriority())
    print("pre-order traversal:")
    h.printHeapPreOrder(h.getRoot())
    
    print(h.getSize())
    
    print("deleteMin")
    h.removeMin()
    
    print(h.getSize())
    
    print("deleteMin")
    h.removeMin()
    
    print(h.getSize())

    print("deleteMin")
    h.removeMin()

    print("deleteMin")
    h.removeMin()

    print("deleteMin")
    h.removeMin()

#     print("insert 35, resume")
#     h.Insert(Hnode(35, "resume"))
    
#     print("insert 15, second")
#     h.Insert(Hnode(15, "second"))

#     print("insert 20, fourth")
#     h.Insert(Hnode(20, "fourth"))

#     print("Heap size=", h.getSize(), "The highest priority is ", h.getHighestPriority())
#     print("pre-order traversal:")
#     h.printHeapPreOrder(h.getRoot())
    
#     print("deleteMin")
#     h.removeMin()

#     print("insert 40, nineth")
#     h.Insert(Hnode(40, "nineth"))
    
    
HeapwithEntriesInserted()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/f0/vz_vv1ts3yd1jytqkj0cqm7h0000gn/T/ipykernel_703/247829484.py in <module>
#     420
#     421
# --> 422 HeapwithEntriesInserted()
#
# /var/folders/f0/vz_vv1ts3yd1jytqkj0cqm7h0000gn/T/ipykernel_703/247829484.py in HeapwithEntriesInserted()
#     368             a, b = line.strip().split()
#     369             n = Hnode(int(a), b)
# --> 370             h.Insert(n)
#     371             if 'str' in line:
#     372                 break
#
# /var/folders/f0/vz_vv1ts3yd1jytqkj0cqm7h0000gn/T/ipykernel_703/247829484.py in Insert(self, hnode)
#     291                 else:
#     292                     parent = node
# --> 293                     node = node.right
#     294
#     295             if parent.hasLeftChild():
#
# AttributeError: 'NoneType' object has no attribute 'right'

# %%
import re

# Node class 
class Hnode:
    def __init__(self, key, item):
        self.key = key
        self.item = item
        self.parent = None
        self.right = None
        self.left = None

    def getKey(self):
        return self.key

    def getItem(self):
        return self.item

    def getRightChild(self):
        return self.right

    def getLeftChild(self):
        return self.left

    def getParent(self):
        return self.parent

    def hasRightChild(self):
        return (self.right!=None)

    def hasLeftChild(self):
        return (self.left!=None)

    def isRoot(self):
        return (self.parent==None)

    def isLeaf(self):
        return ((self.right==None)and(self.left==None))

    def isRightChild(self):
        return (self.parent.right==self)

    def isLeftChild(self):
        return (self.parent.left==self)

    def setParent(self, p):
        self.parent=p

    def setKey(self, key):
        self.key = key

    def setItem(self, item):
        self.item = item
        
    def addRightChild(self, hnode):
        self.right=hnode
        hnode.setParent(self)

    def addLeftChild(self, hnode):
        self.left=hnode
        hnode.setParent(self)

# Heap class 
class Heap:
    def __init__(self):
        self.root=None
        self.last=None
        self.size=0

    def isEmpty(self):
        return (self.size==0)

    def getSize(self):
        return self.size

    def getRoot(self):
        return self.root

    def getLast(self):
        return self.last

    def getHighestPriority(self):
        return self.root.getKey()

    def setRoot(self, hnode):
        self.root=hnode

    def setLast(self, hnode):
        self.last=hnode

#
# methods for heaps
#

    #
    # downward adjustment from current node
    #
    def downwardHeapify(self,current):


    #
    # upward adjustment toward the root from the current node
    #
    def upwardHeapify(self, current):


    #
    # The most important operation for a heap, remove_Min (extract_Min())
    #
    def removeMin(self):


    #
    # Another important operation for a heap, insertion() (add())
    #
    def Insert(self, hnode):
        

    #
    # For management, print the heap in pre-order
    #
    def printHeapPreOrder(self, i):


# decimal to binary using yield
def d2by(x):
    while x>0 :
        x,r=divmod(x,2)
        yield r 

# function for starting the task
def HeapwithEntriesInserted():
    #
    # read the input information from the default input text file into an
    # entry list, entry_list
    #
    
    #
    # initiating a heap object h
    #
    h=Heap()

    #
    # Do something here to build the heap
    #
    

    #---------------------Print as the example on the homework sheet --------
    #                       will be adapted with the input
    #
    print("Heap size=", h.getSize(), "The highest priority is ", h.getHighestPriority())
    print("pre-order traversal:")
    h.printHeapPreOrder(h.getRoot())

    print("deleteMin")
    h.removeMin()

    print("deleteMin")
    h.removeMin()

    print("deleteMin")
    h.removeMin()

    print("deleteMin")
    h.removeMin()

    print("deleteMin")
    h.removeMin()

    print("insert 35, resume")
    h.Insert(Hnode(35, "resume"))
    
    print("insert 15, second")
    h.Insert(Hnode(15, "second"))

    print("insert 20, fourth")
    h.Insert(Hnode(20, "fourth"))

    print("Heap size=", h.getSize(), "The highest priority is ", h.getHighestPriority())
    print("pre-order traversal:")
    h.printHeapPreOrder(h.getRoot())
    
    print("deleteMin")
    h.removeMin()

    print("insert 40, nineth")
    h.Insert(Hnode(40, "nineth"))

HeapwithEntriesInserted()
# Out:
# Heap size= 4 The highest priority is  10
# pre-order traversal:
# Node [ 10 mary ]
# Node [ 25 john ]
# Leaf [ 50 lowe ]
# Leaf [ 35 mars ]
# deleteMin
# deleteMin
# deleteMin
# deleteMin
# The heap is now empty
# deleteMin
# The heap is empty and no entry can be removed
# insert 35, resume
# insert 15, second
# insert 20, fourth
# Heap size= 3 The highest priority is  15
# pre-order traversal:
# Node [ 15 second ]
# Leaf [ 35 resume ]
# Leaf [ 20 fourth ]
# deleteMin
# insert 40, nineth
